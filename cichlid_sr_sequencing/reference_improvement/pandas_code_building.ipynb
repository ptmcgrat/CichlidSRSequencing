# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/kmnike/Desktop/UMD2a_remap_v1.xlsx', sheet_name = 'NC_036780.1')
df
# Out:
#              LG     Start      Stop  region_size  umd2a_based_region_order  \
# 0   NC_036780.1         1    613372       613372                         1
# 1   NC_036780.1    613473   1343998       730526                         2
# 2   NC_036780.1   1344099   2170558       826460                         3
# 3   NC_036780.1   2170659   4254576      2083918                         4
# 4   NC_036780.1   4254677   4318228        63552                         5
# 5   NC_036780.1   4318329   6081317      1762989                         6
# 6   NC_036780.1   6081418   7198436      1117019                         7
# 7   NC_036780.1   7198537   8010754       812218                         8
# 8   NC_036780.1   8010855  14483744      6472890                         9
# 9   NC_036780.1  14483845  17493598      3009754                        10
# 10  NC_036780.1  17493699  17534073        40375                        11
# ...

# %%
remapping_list = []
for index, rows in df.iterrows():
    a = [rows.Start, rows.Stop, rows.sample_based_regin_order, rows.region_attributes, rows.approx_missing_len]
    remapping_list.append(a)
remapping_list
# Out:
# [[1, 613372, 4, 'Normal', 0],
#  [613473, 1343998, 1, 'Inverted', 0],
#  [1344099, 2170558, 3, 'Inverted', 0],
#  [2170659, 4254576, 2, 'Normal', 0],
#  [4254677, 4318228, 5, 'Missing', 700000],
#  [4318329, 6081317, 5, 'Normal', 0],
#  [6081418, 7198436, 6, 'Normal', 0],
#  [7198537, 8010754, 7, 'Normal', 0],
#  [8010855, 14483744, 8, 'Normal', 0],
#  [14483845, 17493598, 9, 'Normal', 0],
#  [17493699, 17534073, 10, 'Translocation', 0],
#  [17534174, 21503482, 11, 'Normal', 0],
#  [21503583, 22073009, 12, 'Inverted', 0],
#  [22073110, 23464123, 13, 'Translocation', 0],
#  [23464224, 23601101, 14, 'Translocation', 0],
#  [23601202, 27030965, 15, 'Normal', 0],
#  [27031066, 27335948, 16, 'Inverted', 0],
#  [27336049, 28711887, 17, 'Normal', 0],
#  [28711988, 29815039, 18, 'Normal', 0],
#  [29815140, 31339039, 19, 'Normal', 0],
#  [31339140, 31601171, 20, 'Normal', 0],
#  [31601272, 33241048, 21, 'Normal', 0],
#  [33241149, 33720478, 22, 'Normal', 0],
# ...
