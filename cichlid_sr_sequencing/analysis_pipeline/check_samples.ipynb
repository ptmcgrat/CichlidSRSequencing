# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/kmnike/Downloads/SampleDatabase_v2_gt3.xlsx')

# %%
df
# Out:
#          SampleID  ReadLength    TotalBases         ProjectID  Platform  \
# 0    SAMEA1904331         200  5.760781e+09         PRJEB1254  ILLUMINA
# 1    SAMEA1877429         200  5.152680e+09         PRJEB1254  ILLUMINA
# 2    SAMEA2661258         250  1.702396e+10         PRJEB1254  ILLUMINA
# 3    SAMEA4032098         302  2.941360e+10        PRJEB15289  ILLUMINA
# 4    SAMEA1904323         200  4.499385e+09         PRJEB1254  ILLUMINA
# ..            ...         ...           ...               ...       ...
# 467      CV_008_m         300           NaN  SexDetermination  ILLUMINA
# 468      OC_006_f         300           NaN  SexDetermination  ILLUMINA
# 469      OC_007_f         300           NaN  SexDetermination  ILLUMINA
# 470      OC_008_m         300           NaN  SexDetermination  ILLUMINA
# 471      OC_003_f         300           NaN  SexDetermination  ILLUMINA
#
#                                     Organism         Ecogroup  \
# ...

# %%
b_df = pd.read_csv('/Users/kmnike/CichlidSRSequencing/cichlid_sr_sequencing/analysis_pipeline/bionanod_samples.csv', header=None)
b_df = b_df.rename(columns = {0 : 'SampleID'})
b_df['SampleID'] = b_df['SampleID'].str.replace('-','_')

# %%
calls = b_df['SampleID'].isin(df.SampleID)
# print(calls.to_string(index=False))
b_df.SampleID
# Out:
# 0        MZ_009_f
# 1        MZ_010_f
# 2          MZ7.1f
# 3        MZ_008_m
# 4            LF3f
# 5        LF_004_m
# 6        LT_009_m
# 7        LT_010_f
# 8           CZc3m
# 9           CZc4f
# 10           PD1m
# 11           PD2f
# 12         CV9.1f
# 13    Kocher_CV1m
# 14    Kocher_CV2f
# 15    Kocher_MC1m
# 16    Kocher_MC2f
# 17        MC10.1f
# 18    Kocher_YH1m
# 19    Kocher_YH2f
# 20        YH15.1m
# 21         OC4.1f
# 22           OC5m
# 23      DT_1001_m
# 24      DT_1002_m
# 25      RC_1101_m
# 26      RC_1102_f
# 27      RC_2203_m
# 28      RC_2204_m
# Name: SampleID, dtype: object
