# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/kmnike/Desktop/VCF_Excel_Sheets/SampleDatabase.xlsx', sheet_name = 'vcf_samples')
df
# Out:
#          SampleID           RunID  ReadLength   TotalBases  \
# 0    SAMEA6147768      ERR3634107         302  31840340482
# 1    SAMEA6147767      ERR3634108         302  27454946840
# 2    SAMEA6147765      ERR3634109         302  29880616578
# 3    SAMEA6147769      ERR3634110         302  27587069424
# 4    SAMEA6147766      ERR3634111         302  32771478660
# ..            ...             ...         ...          ...
# 517        CV_1_m  PM18_CV_1_m_L1         502            0
# 518        CV_2_f  PM18_CV_2_f_L1         502            0
# 519        MC_1_m  PM18_MC_1_m_L1         502            0
# 520        MC_2_f  PM18_MC_2_f_L1         502            0
# 521        YH_1_m  PM18_YH_1_m_L1         502            0
#
#                 ProjectID        Instrument       LibraryID LibraryLayout  \
# 0              PRJEB15289       HiSeq X Ten    DN461383W:E1        PAIRED
# 1              PRJEB15289       HiSeq X Ten    DN461383W:F1        PAIRED
# 2              PRJEB15289       HiSeq X Ten    DN461383W:G1        PAIRED
# 3              PRJEB15289       HiSeq X Ten    DN461383W:A2        PAIRED
# 4              PRJEB15289       HiSeq X Ten    DN461383W:B2        PAIRED
# ..                    ...               ...             ...           ...
# 517  ReferenceImprovement  Illumina NovaSeq  CV_1_m_Library        PAIRED
# 518  ReferenceImprovement  Illumina NovaSeq  CV_2_f_Library        PAIRED
# 519  ReferenceImprovement  Illumina NovaSeq  MC_1_m_Library        PAIRED
# 520  ReferenceImprovement  Illumina NovaSeq  MC_2_f_Library        PAIRED
# 521  ReferenceImprovement  Illumina NovaSeq  YH_1_m_Library        PAIRED
#
#     LibrarySource  Platform  \
# 0         GENOMIC  ILLUMINA
# 1         GENOMIC  ILLUMINA
# 2         GENOMIC  ILLUMINA
# 3         GENOMIC  ILLUMINA
# 4         GENOMIC  ILLUMINA
# ..            ...       ...
# 517       GENOMIC  ILLUMINA
# 518       GENOMIC  ILLUMINA
# 519       GENOMIC  ILLUMINA
# 520       GENOMIC  ILLUMINA
# 521       GENOMIC  ILLUMINA
#
#                                                   File  \
# 0    PRJEB15289/ERR3634107.unmapped_marked_adapters...
# 1    PRJEB15289/ERR3634108.unmapped_marked_adapters...
# 2    PRJEB15289/ERR3634109.unmapped_marked_adapters...
# 3    PRJEB15289/ERR3634110.unmapped_marked_adapters...
# 4    PRJEB15289/ERR3634111.unmapped_marked_adapters...
# ..                                                 ...
# 517  ReferenceImprovement/PM18_CV_1_m_L1.unmapped_m...
# 518  ReferenceImprovement/PM18_CV_2_f_L1.unmapped_m...
# 519  ReferenceImprovement/PM18_MC_1_m_L1.unmapped_m...
# 520  ReferenceImprovement/PM18_MC_2_f_L1.unmapped_m...
# 521  ReferenceImprovement/PM18_YH_1_m_L1.unmapped_m...
#
#                                      Organism      Ecogroup  \
# 0                    Astatotilapia rukwa blue            AC
# 1                  Astatotilapia rukwa sunset      Riverine
# 2            Astatotilapia rukwa large yellow      Riverine
# 3                    Astatotilapia ruaha blue      Riverine
# 4                    Haplochromis vanheusdeni      Riverine
# ..                                        ...           ...
# 517                  Copadichromis virginalis         Utaka
# 518                  Copadichromis virginalis         Utaka
# 519                        Mchenga conophoros         Utaka
# 520                        Mchenga conophoros         Utaka
# 521  Aulonocara Nkhata "yellow head" chitende  Deep Benthic
#
#     Link To Ecogroup Source              EG   #Organisms
# 0               Unnamed: 13               AC        27.0
# 1                       NaN         Riverine       175.0
# 2                       NaN     Diplotaxodon        27.0
# 3                       NaN    Rhampochromis        19.0
# 4                       NaN  Shallow Benthic       157.0
# ..                      ...              ...         ...
# 517                     NaN              NaN         NaN
# 518                     NaN              NaN         NaN
# 519                     NaN              NaN         NaN
# 520                     NaN              NaN         NaN
# 521                     NaN              NaN         NaN
#
# [522 rows x 16 columns]

# %%
eg = ['Mbuna', 'Utaka', 'Shallow Benthic', 'Deep Benthic','Rhampochromis', 'Diplotaxodon']
df_filtered = df[df.Ecogroup.isin(eg)]
pd.DataFrame(df_filtered.SampleID.unique()).to_csv('good_samples.cvs', header = False, index = False)
df_filtered['metadata_id'] = df_filtered['SampleID'] + "_" + df_filtered['Ecogroup']
df_filtered[['SampleID', 'metadata_id']].to_csv('filtered_samples.csv')
# pd.DataFrame(df[df.Ecogroup.isin(eg)].SampleID.unique()).to_csv('good_samples_csv', header = False, index = False)
# df_filtered = df[df['Ecogroup'].isin(eg)]
# df_filtered['metadata_id'] = df_filtered['SampleID'] + "_" + df_filtered['Ecogroup']
# df_filtered[['SampleID', 'metadata_id']].to_csv('filtered_samples.csv')
# only_samples = df_filtered['SampleID']
# Out:
# /var/folders/16/ks7jmj6s55qg8gc9bckr9tjw0000gn/T/ipykernel_36717/3529962476.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['metadata_id'] = df_filtered['SampleID'] + "_" + df_filtered['Ecogroup']
