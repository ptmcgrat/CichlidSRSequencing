# %%
import pandas as pd

# %%
s_df = pd.read_excel('/Users/kmnike/Desktop/SampleDatabase_v2.xlsx', sheet_name='SampleLevel')
s_df = s_df[s_df['Platform'].isin(['ILLUMINA'])].drop_duplicates(subset='SampleID')
a_df = pd.read_excel('/Users/kmnike/Desktop/AlignmentDatabase.xlsx')

# %%
gt3_samples = a_df[a_df['GenomeVersion'] == 'Mzebra_GT3'].SampleID

# %%
# s_df[s_df['SampleID']].isin(gt3_samples)

filtrered_s_df = s_df[s_df['SampleID'].isin(gt3_samples)]

# %%
filtrered_s_df['Genome_version'] = 'Mzebra_GT3'
# Out:
# /var/folders/z6/zmrhmd0s1h922smcdvk5hvl80000gn/T/ipykernel_30139/402789964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtrered_s_df['Genome_version'] = 'Mzebra_GT3'

# %%
filtrered_s_df
# Out:
#          SampleID  ReadLength    TotalBases         ProjectID  Platform  \
# 0    SAMEA1904331         200  5.760781e+09         PRJEB1254  ILLUMINA
# 1    SAMEA1877429         200  5.152680e+09         PRJEB1254  ILLUMINA
# 2    SAMEA2661258         250  1.702396e+10         PRJEB1254  ILLUMINA
# 4    SAMEA4032098         302  2.941360e+10        PRJEB15289  ILLUMINA
# 145  SAMEA1904323         200  4.499385e+09         PRJEB1254  ILLUMINA
# ..            ...         ...           ...               ...       ...
# 746        YH_057         300           NaN  SexDetermination  ILLUMINA
# 748        YH_058         300           NaN  SexDetermination  ILLUMINA
# 750        YH_059         300           NaN  SexDetermination  ILLUMINA
# 752        YH_060         300           NaN  SexDetermination  ILLUMINA
# 754        YH_061         300           NaN  SexDetermination  ILLUMINA
#
#                                     Organism         Ecogroup  \
# ...

# %%
filtrered_s_df.to_excel('/Users/kmnike/Desktop/SampleDatabase_v2_gt3.xlsx', index=False)
