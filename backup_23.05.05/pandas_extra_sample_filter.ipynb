# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/kmnike/Desktop/VCF_Excel_Sheets/SampleDatabase.xlsx')
df
# Out:
#          SampleID       RunID  ReadLength   TotalBases   ProjectID  \
# 0    SAMEA1904331   ERR299206         200   5760780600   PRJEB1254
# 1    SAMEA1904331   ERR299215         200   5754979800   PRJEB1254
# 2    SAMEA1904331   ERR295132         200   5607303800   PRJEB1254
# 3    SAMEA1877429   ERR266498         200   5152679800   PRJEB1254
# 4    SAMEA1877429   ERR271651         200   5251306000   PRJEB1254
# ..            ...         ...         ...          ...         ...
# 680  SAMEA4033302  ERR1757757         302  31711443560  PRJEB15289
# 681  SAMEA4032105  ERR1749547         302  33527928562  PRJEB15289
# 682  SAMEA4033301  ERR1749548         302  31361555118  PRJEB15289
# 683  SAMEA4032106  ERR1749549         302  34238240112  PRJEB15289
# 684  SAMEA3388855  ERR1081367         250  14060940500   PRJEB1254
#
#               Instrument     LibraryID LibraryLayout LibrarySource  Platform  \
# 0    Illumina HiSeq 2000       6811014        PAIRED       GENOMIC  ILLUMINA
# ...

# %%
df_no_dup = df.drop_duplicates('SampleID')
df_no_dup
df_no_dup.to_excel('/Users/kmnike/Desktop/VCF_Excel_Sheets/SampleDatabase_no_duplicates.xlsx',index=False)

# %%
df = pd.read_excel('/Users/kmnike/Desktop/VCF_Excel_Sheets/SampleDatabase.xlsx', sheet_name="no_duplicates")
df
# new_IDs = df['SampleID'].copy()
# old_IDs = df['Old_sample_IDs'].copy()

# %%
missing_values = df.loc[~df['SampleID'].isin(df['Old_sample_IDs']), 'SampleID']
print(missing_values)

# %%
# df_all = df1.merge(df2.drop_duplicates(), on=['col1','col2'], 
#                    how='left', indicator=True)
# df_all

#    col1  col2     _merge
# 0     1    10       both
# 1     2    11       both
# 2     3    12       both
# 3     4    13  left_only
# 4     5    14  left_only
# 5     3    10  left_only
# Create a boolean condition:

# df_all['_merge'] == 'left_only'
